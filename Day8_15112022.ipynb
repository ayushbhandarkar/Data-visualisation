# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randint
# %matplotlib inline

# %%
x = np.linspace(1, 10, 20)

# %%
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1,50,20)

# %%
y
# Out:
# array([24,  8, 44, 27, 23, 48, 22, 21,  8, 40, 36, 44, 38, 42, 26,  7, 34,
#        21,  6, 43])

# %%
x.size, y.size
# Out:
# (20, 20)

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
y = y.cumsum()

# %%
plt.plot(y)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, color='r')

# %%
plt.plot(x,y, color='r', marker = 'o')

# %% [markdown]
# # Q what is the information you are getting from this graph x and y values

# %%
plt.plot(x,y, color='r', marker = 'o', linestyle = '--')

# %%
plt.plot(x,y, color='r', marker = 'o', linestyle = '--')
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.scatter(x,y, color='g', linewidth=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#bar
b = [10,22,5,17,57]
a = ['a', 'b', 'c', 'd', 'e']
plt.bar(a,b, color = 'r', width=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.hist(y, rwidth=0.7, bins=30)
plt.show()
